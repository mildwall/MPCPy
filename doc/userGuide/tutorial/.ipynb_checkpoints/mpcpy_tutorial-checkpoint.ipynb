# %%
from mpcpy import variables
from mpcpy import units

# %%
setpoint = variables.Static('setpoint', 20, units.degC)
print(setpoint)
# Out:
# Name: setpoint
# Variability: Static
# Quantity: Temperature
# Display Unit: degC

# %%
setpoint.display_data()
# Out:
# 20.0

# %%
setpoint.get_base_data()
# Out:
# 293.15

# %%
setpoint.set_display_unit(units.degF)
setpoint.display_data()
# Out:
# 68.0

# %%
import pandas as pd

# %%
data = [0, 5, 10, 15, 20]
index = pd.date_range(start='1/1/2017', periods=len(data), freq='H')
ts = pd.Series(data=data, index=index, name='power_data')

# %%
power_data = variables.Timeseries('power_data', ts, units.Btuh)
print(power_data)
# Out:
# Name: power_data
# Variability: Timeseries
# Quantity: Power
# Display Unit: Btuh

# %%
power_data.display_data()
# Out:
# 2017-01-01 00:00:00+00:00     0.0
# 2017-01-01 01:00:00+00:00     5.0
# 2017-01-01 02:00:00+00:00    10.0
# 2017-01-01 03:00:00+00:00    15.0
# 2017-01-01 04:00:00+00:00    20.0
# Freq: H, Name: power_data, dtype: float64

# %%
power_data.get_base_data()
# Out:
# 2017-01-01 00:00:00+00:00    0.000000
# 2017-01-01 01:00:00+00:00    1.465355
# 2017-01-01 02:00:00+00:00    2.930711
# 2017-01-01 03:00:00+00:00    4.396066
# 2017-01-01 04:00:00+00:00    5.861421
# Freq: H, Name: power_data, dtype: float64

# %%
power_data.set_display_unit(units.kW)
power_data.display_data()
# Out:
# 2017-01-01 00:00:00+00:00    0.000000
# 2017-01-01 01:00:00+00:00    0.001465
# 2017-01-01 02:00:00+00:00    0.002931
# 2017-01-01 03:00:00+00:00    0.004396
# 2017-01-01 04:00:00+00:00    0.005861
# Freq: H, Name: power_data, dtype: float64

# %%
from mpcpy import exodata
weather = exodata.WeatherFromEPW('USA_IL_Chicago-OHare.Intl.AP.725300_TMY3.epw')
# Out:
# /home/guokaichen/.local/lib/python2.7/site-packages/pvlib/forecast.py:22: UserWarning: The forecast module algorithms and features are highly experimental. The API may change, the functionality may be consolidated into an io module, or the module may be separated into its own package.
#   'module, or the module may be separated into its own package.')

# %%
variable_map = {'Qflow_csv' : ('Qflow', units.W)}
control = exodata.ControlFromCSV('ControlSignal.csv',
          variable_map,
        tz_name = weather.tz_name)

# %%
start_time = '1/1/2017'
final_time = '1/3/2017'
weather.collect_data(start_time, final_time)
control.collect_data(start_time, final_time)
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 3
#  Number of function evaluations                  : 7
#  Number of Jacobian evaluations                  : 1
#  Number of function eval. due to Jacobian eval.  : 1
#  Number of error test failures                   : 0
#  Number of nonlinear iterations                  : 3
#  Number of nonlinear convergence failures        : 0
#  Number of state function evaluations            : 4
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 1e-08
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 172800.0 seconds.
# Elapsed simulation time: 0.00907492637634 seconds.

# %%
control.display_data()
# Out:
#                             Qflow
# Time
# 2017-01-01 06:00:00+00:00  3000.0
# 2017-01-01 07:00:00+00:00  3000.0
# 2017-01-01 08:00:00+00:00  3000.0
# 2017-01-01 09:00:00+00:00  3000.0
# 2017-01-01 10:00:00+00:00  3000.0
# 2017-01-01 11:00:00+00:00  3000.0
# 2017-01-01 12:00:00+00:00  3000.0
# 2017-01-01 13:00:00+00:00  3000.0
# 2017-01-01 14:00:00+00:00  3000.0
# 2017-01-01 15:00:00+00:00  3000.0
# 2017-01-01 16:00:00+00:00  3000.0
# 2017-01-01 17:00:00+00:00  3000.0
# 2017-01-01 18:00:00+00:00  3000.0
# 2017-01-01 19:00:00+00:00  3000.0
# 2017-01-01 20:00:00+00:00  3000.0
# 2017-01-01 21:00:00+00:00  3000.0
# 2017-01-01 22:00:00+00:00  3000.0
# 2017-01-01 23:00:00+00:00  3000.0
# 2017-01-02 00:00:00+00:00  3000.0
# 2017-01-02 01:00:00+00:00  3000.0
# 2017-01-02 02:00:00+00:00  3000.0
# 2017-01-02 03:00:00+00:00  3000.0
# 2017-01-02 04:00:00+00:00  3000.0
# 2017-01-02 05:00:00+00:00  3000.0
# 2017-01-02 06:00:00+00:00  3000.0
# 2017-01-02 07:00:00+00:00  3000.0
# 2017-01-02 08:00:00+00:00  3000.0
# 2017-01-02 09:00:00+00:00  3000.0
# 2017-01-02 10:00:00+00:00  3000.0
# 2017-01-02 11:00:00+00:00  3000.0
# 2017-01-02 12:00:00+00:00  3000.0
# 2017-01-02 13:00:00+00:00  3000.0
# 2017-01-02 14:00:00+00:00  3000.0
# 2017-01-02 15:00:00+00:00  3000.0
# 2017-01-02 16:00:00+00:00  3000.0
# 2017-01-02 17:00:00+00:00  3000.0
# 2017-01-02 18:00:00+00:00  3000.0
# 2017-01-02 19:00:00+00:00  3000.0
# 2017-01-02 20:00:00+00:00  3000.0
# 2017-01-02 21:00:00+00:00  3000.0
# 2017-01-02 22:00:00+00:00  3000.0
# 2017-01-02 23:00:00+00:00  3000.0
# 2017-01-03 00:00:00+00:00  3000.0
# 2017-01-03 01:00:00+00:00  3000.0
# 2017-01-03 02:00:00+00:00  3000.0
# 2017-01-03 03:00:00+00:00  3000.0
# 2017-01-03 04:00:00+00:00  3000.0
# 2017-01-03 05:00:00+00:00  3000.0
# 2017-01-03 06:00:00+00:00  3000.0

# %%
from mpcpy import systems

# %%
measurements = {'Tzone' : {}, 'Qflow' : {}}
measurements['Tzone']['Sample'] = variables.Static('sample_rate_Tzone',3600,units.s)

# %%
measurements['Qflow']['Sample'] = variables.Static('sample_rate_Qflow',3600,units.s)

# %%
moinfo = ('Tutorial.mo', 'Tutorial.RC', {})

# %%
emulation = systems.EmulationFromFMU(measurements,
            moinfo = moinfo,
            weather_data = weather.data,
            control_data = control.data,
            tz_name = weather.tz_name)
# Out:
# Warning: The option 'extra_lib_dirs' has been deprecated and will be removed. Please use the 'file_name' to pass additional libraries.

# %%
emulation.collect_measurements('1/1/2017', '1/2/2017')
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 342
#  Number of function evaluations                  : 510
#  Number of Jacobian evaluations                  : 7
#  Number of function eval. due to Jacobian eval.  : 7
#  Number of error test failures                   : 43
#  Number of nonlinear iterations                  : 506
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 3e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0296359062195 seconds.

# %%
emulation.display_measurements('Measured').applymap('{:.2f}'.format)
# Out:
#                              Qflow   Tzone
# Time
# 2017-01-01 06:00:00+00:00  3000.00  293.15
# 2017-01-01 07:00:00+00:00  3000.00  291.01
# 2017-01-01 08:00:00+00:00  3000.00  291.32
# 2017-01-01 09:00:00+00:00  3000.00  291.88
# 2017-01-01 10:00:00+00:00  3000.00  292.05
# 2017-01-01 11:00:00+00:00  3000.00  292.41
# 2017-01-01 12:00:00+00:00  3000.00  292.55
# 2017-01-01 13:00:00+00:00  3000.00  292.55
# 2017-01-01 14:00:00+00:00  3000.00  292.99
# 2017-01-01 15:00:00+00:00  3000.00  293.95
# 2017-01-01 16:00:00+00:00  3000.00  295.85
# 2017-01-01 17:00:00+00:00  3000.00  297.67
# 2017-01-01 18:00:00+00:00  3000.00  299.38
# 2017-01-01 19:00:00+00:00  3000.00  300.64
# 2017-01-01 20:00:00+00:00  3000.00  301.74
# 2017-01-01 21:00:00+00:00  3000.00  302.04
# 2017-01-01 22:00:00+00:00  3000.00  302.05
# 2017-01-01 23:00:00+00:00  3000.00  302.05
# 2017-01-02 00:00:00+00:00  3000.00  301.61
# 2017-01-02 01:00:00+00:00  3000.00  301.09
# 2017-01-02 02:00:00+00:00  3000.00  301.76
# 2017-01-02 03:00:00+00:00  3000.00  301.60
# 2017-01-02 04:00:00+00:00  3000.00  301.89
# 2017-01-02 05:00:00+00:00  3000.00  301.61
# 2017-01-02 06:00:00+00:00  3000.00  301.45

# %%
from mpcpy import models

# %%
parameters = exodata.ParameterFromCSV('Parameters.csv')
parameters.collect_data()
parameters.display_data()
# Out:
#                   Covariance  Free Maximum Minimum Unit  Value
# Name
# heatCapacitor.C         1000  True   1e+06   10000  J/K  40000
# thermalResistor.R     0.0001  True     0.1   0.001  K/W  0.002

# %%
model = models.Modelica(models.JModelicaParameter,
... models.RMSE,
... emulation.measurements,
... moinfo = moinfo,
... parameter_data = parameters.data,
... weather_data = weather.data,
... control_data = control.data,
... tz_name = weather.tz_name)
# Out:
# Warning: The option 'extra_lib_dirs' has been deprecated and will be removed. Please use the 'file_name' to pass additional libraries.
# Warning: The option 'extra_lib_dirs' has been deprecated and will be removed. Please use the 'file_name' to pass additional libraries.

# %%
# Simulate the model
model.simulate('1/1/2017', '1/2/2017')
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 547
#  Number of function evaluations                  : 881
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 11
#  Number of error test failures                   : 109
#  Number of nonlinear iterations                  : 877
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 3e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0513489246368 seconds.

# %%
model.parameter_estimate('1/1/2017', '1/2/2017', ['Tzone'])
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 505
#  Number of function evaluations                  : 805
#  Number of Jacobian evaluations                  : 10
#  Number of function eval. due to Jacobian eval.  : 20
#  Number of error test failures                   : 102
#  Number of nonlinear iterations                  : 801
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [1.e-08 3.e-06]
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0398490428925 seconds.
# Warning: Nominal trajectory for variable J is identically zero. Using nominal attribute instead.
# Warning: Nominal trajectory for variable der(J) is identically zero. Using nominal attribute instead.
#
# Initialization time: 0.17 seconds
#
# Total time: 0.23 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.05 seconds
# Post-processing time: 0.01 seconds

# %%
# Perform validation
model.validate('1/1/2017', '1/2/2017', 'validate_tra', plot=1)
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 310
#  Number of function evaluations                  : 486
#  Number of Jacobian evaluations                  : 6
#  Number of function eval. due to Jacobian eval.  : 6
#  Number of error test failures                   : 43
#  Number of nonlinear iterations                  : 482
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 3e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0323748588562 seconds.

# %%
# Get RMSE
print("%.3f" % model.RMSE['Tzone'].display_data())
# Out:
# 0.041

# %%
# Define validation period
start_time_val = '1/2/2017'
final_time_val = '1/3/2017'

# %%
# Collect new measurements
emulation.collect_measurements(start_time_val, final_time_val)
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 403
#  Number of function evaluations                  : 630
#  Number of Jacobian evaluations                  : 8
#  Number of function eval. due to Jacobian eval.  : 8
#  Number of error test failures                   : 53
#  Number of nonlinear iterations                  : 626
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 3e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.033586025238 seconds.

# %%
# Assign new measurements to model
model.measurements = emulation.measurements
# Perform validation
model.validate(start_time_val, final_time_val, 'validate_val', plot=1)
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 383
#  Number of function evaluations                  : 612
#  Number of Jacobian evaluations                  : 8
#  Number of function eval. due to Jacobian eval.  : 8
#  Number of error test failures                   : 58
#  Number of nonlinear iterations                  : 608
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 3e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0307610034943 seconds.

# %%
# Get RMSE
print("%.3f" % model.RMSE['Tzone'].display_data())
# Out:
# 0.047

# %%
for key in model.parameter_data.keys():
    print(key, "%.2f" % model.parameter_data[key]['Value'].display_data())
# Out:
# ('heatCapacitor.C', '119792.17')
# ('thermalResistor.R', '0.01')

# %%
from mpcpy import optimization

# %%
# Define variable map
variable_map = {'Qflow_min' : ('Qflow', 'GTE', units.W),'Qflow_max' : ('Qflow', 'LTE', units.W),
    'T_min' : ('Tzone', 'GTE', units.degC),'T_max' : ('Tzone', 'LTE', units.degC)}

# %%
# Instantiate constraint exodata object
constraints = exodata.ConstraintFromCSV('Constraints.csv',variable_map,tz_name = weather.tz_name)
# Collect data
constraints.collect_data('1/1/2017', '1/3/2017')
# Get data
constraints.display_data()
# Out:
#                            Qflow_GTE  Qflow_LTE  Tzone_GTE  Tzone_LTE
# Time
# 2017-01-01 06:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 07:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 08:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 09:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 10:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 11:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 12:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 13:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 14:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 15:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 16:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 17:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 18:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 19:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 20:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 21:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 22:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-01 23:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 00:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 01:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 02:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 03:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 04:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 05:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 06:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 07:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 08:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 09:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 10:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 11:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 12:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 13:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 14:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 15:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 16:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 17:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 18:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 19:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 20:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 21:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 22:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-02 23:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-03 00:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-03 01:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-03 02:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-03 03:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-03 04:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-03 05:00:00+00:00        0.0     4000.0       20.0       25.0
# 2017-01-03 06:00:00+00:00        0.0     4000.0       20.0       25.0

# %%
opt_problem = optimization.Optimization(model,
                                        optimization.EnergyMin,
                                        optimization.JModelica,
                                        'Qflow',
                                        constraint_data = constraints.data)
# Out:
# Warning: The option 'extra_lib_dirs' has been deprecated and will be removed. Please use the 'file_name' to pass additional libraries.

# %%
opt_problem.optimize('1/2/2017', '1/3/2017')
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 346
#  Number of function evaluations                  : 523
#  Number of Jacobian evaluations                  : 7
#  Number of function eval. due to Jacobian eval.  : 14
#  Number of error test failures                   : 43
#  Number of nonlinear iterations                  : 522
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [1.e-08 3.e-06]
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0292899608612 seconds.
#
# Initialization time: 0.13 seconds
#
# Total time: 0.19 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.05 seconds
# Post-processing time: 0.01 seconds

# %%
opt_problem.get_optimization_statistics()
# Out:
# ('Solve_Succeeded', 12, 174092214.0655953, 0.048938)

# %%
opt_problem.display_measurements('Simulated').applymap('{:.2f}'.format)
# Out:
#                                     Qflow   Tzone
# Time
# 2017-01-02 06:00:00+00:00          670.38  298.15
# 2017-01-02 06:09:18.183693+00:00  1513.15  293.15
# 2017-01-03 02:00:00+00:00           1888.07
# 2017-01-03 02:09:18.183693+00:00    1878.77
# 2017-01-03 02:38:41.816307+00:00    1849.41
# 2017-01-03 03:00:00+00:00           1828.13
# 2017-01-03 03:09:18.183693+00:00    1820.38
# 2017-01-03 03:38:41.816307+00:00    1795.91
# 2017-01-03 04:00:00+00:00           1778.18
# 2017-01-03 04:09:18.183693+00:00    1812.26
# 2017-01-03 04:38:41.816307+00:00    1919.92
# 2017-01-03 05:00:00+00:00           1997.95
# 2017-01-03 05:09:18.183693+00:00    1997.95
# 2017-01-03 05:38:41.816307+00:00    1997.95
# 2017-01-03 06:00:00+00:00           1997.95
# Name: Qflow, Length: 73, dtype: object

# %%
model.simulate('1/2/2017', '1/3/2017')
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 476
#  Number of function evaluations                  : 764
#  Number of Jacobian evaluations                  : 9
#  Number of function eval. due to Jacobian eval.  : 9
#  Number of error test failures                   : 73
#  Number of nonlinear iterations                  : 760
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 3e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0389349460602 seconds.

# %%
model.display_measurements('Simulated').applymap('{:.2f}'.format)
# Out:
#                              Qflow   Tzone
# Time
# 2017-01-02 06:00:00+00:00   670.38  293.15
# 2017-01-02 07:00:00+00:00  1888.42  291.41
# 2017-01-02 08:00:00+00:00  2277.67  293.03
# 2017-01-02 09:00:00+00:00  2327.62  293.13
# 2017-01-02 10:00:00+00:00  2277.67  293.16
# 2017-01-02 11:00:00+00:00  2107.84  293.20
# 2017-01-02 12:00:00+00:00  2107.84  293.15
# 2017-01-02 13:00:00+00:00  2057.89  293.17
# 2017-01-02 14:00:00+00:00  2057.89  293.15
# 2017-01-02 15:00:00+00:00  1997.95  293.17
# 2017-01-02 16:00:00+00:00  1938.02  293.17
# 2017-01-02 17:00:00+00:00  1828.13  293.18
# 2017-01-02 18:00:00+00:00  1828.13  293.15
# 2017-01-02 19:00:00+00:00  1828.13  293.15
# 2017-01-02 20:00:00+00:00  1997.95  293.10
# 2017-01-02 21:00:00+00:00  2057.89  293.13
# 2017-01-02 22:00:00+00:00  1938.02  293.19
# 2017-01-02 23:00:00+00:00  1938.02  293.15
# 2017-01-03 00:00:00+00:00  2057.89  293.11
# 2017-01-03 01:00:00+00:00  1938.02  293.18
# 2017-01-03 02:00:00+00:00  1888.07  293.17
# 2017-01-03 03:00:00+00:00  1828.13  293.17
# 2017-01-03 04:00:00+00:00  1778.18  293.16
# 2017-01-03 05:00:00+00:00  1997.95  293.08
# 2017-01-03 06:00:00+00:00  1997.95  293.15

# %%
opt_problem.optimize('1/2/2017', '1/3/2017', res_control_step=1.0)
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 482
#  Number of function evaluations                  : 732
#  Number of Jacobian evaluations                  : 10
#  Number of function eval. due to Jacobian eval.  : 20
#  Number of error test failures                   : 60
#  Number of nonlinear iterations                  : 731
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [1.e-08 3.e-06]
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0401020050049 seconds.
#
# Initialization time: 0.12 seconds
#
# Total time: 0.17 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 3e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.00821208953857 seconds.

# %%
model.display_measurements('Simulated').applymap('{:.2f}'.format)
# Out:
#                              Qflow   Tzone
# Time
# 2017-01-02 06:00:00+00:00   670.38  293.15
# 2017-01-02 07:00:00+00:00  1888.42  292.67
# 2017-01-02 08:00:00+00:00  2277.67  293.13
# 2017-01-02 09:00:00+00:00  2327.62  293.15
# 2017-01-02 10:00:00+00:00  2277.67  293.15
# 2017-01-02 11:00:00+00:00  2107.84  293.15
# 2017-01-02 12:00:00+00:00  2107.84  293.15
# 2017-01-02 13:00:00+00:00  2057.89  293.15
# 2017-01-02 14:00:00+00:00  2057.89  293.15
# 2017-01-02 15:00:00+00:00  1997.95  293.15
# 2017-01-02 16:00:00+00:00  1938.02  293.15
# 2017-01-02 17:00:00+00:00  1828.13  293.15
# 2017-01-02 18:00:00+00:00  1828.13  293.15
# 2017-01-02 19:00:00+00:00  1828.13  293.15
# 2017-01-02 20:00:00+00:00  1997.95  293.15
# 2017-01-02 21:00:00+00:00  2057.89  293.15
# 2017-01-02 22:00:00+00:00  1938.02  293.15
# 2017-01-02 23:00:00+00:00  1938.02  293.15
# 2017-01-03 00:00:00+00:00  2057.89  293.15
# 2017-01-03 01:00:00+00:00  1938.02  293.15
# 2017-01-03 02:00:00+00:00  1888.07  293.15
# 2017-01-03 03:00:00+00:00  1828.13  293.15
# 2017-01-03 04:00:00+00:00  1778.18  293.15
# 2017-01-03 05:00:00+00:00  1997.95  293.15
# 2017-01-03 06:00:00+00:00  1997.95  293.15

# %%
import matplotlib.pyplot as plt
plt.plot(model.display_measurements('Simulated').applymap('{:.2f}'.format))
# Out:
# [<matplotlib.lines.Line2D at 0x7f67b0291d90>,
#  <matplotlib.lines.Line2D at 0x7f67b0265b10>]

# %%
import matplotlib as mpl
mpl.rcParams['figure.figsize']=(16,12)

# %%
plt.plot(model.display_measurements('Simulated')['Tzone'])

# %% [markdown]
# ***Setback Control***

# %%
variable_map = {'Qflow_min' : ('Qflow', 'GTE', units.W),
                'Qflow_max' : ('Qflow', 'LTE', units.W),
                'T_min' : ('Tzone', 'sGTE', units.degC,100),
                'T_max' : ('Tzone', 'sLTE', units.degC,100)}

# %%
# Instantiate constraint exodata object
constraints = exodata.ConstraintFromCSV('Constraints_setback.csv',variable_map,tz_name = 'UTC')
# Collect data
constraints.collect_data('1/1/2017', '1/3/2017')
# Get data
constraints.display_data()
# Out:
#                            Qflow_GTE  Qflow_LTE  Tzone_sGTE  Tzone_sLTE
# Time
# 2017-01-01 00:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 01:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 02:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 03:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 04:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 05:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 06:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 07:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 08:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 09:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 10:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 11:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 12:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 13:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 14:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 15:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 16:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 17:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 18:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-01 19:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 20:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 21:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 22:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-01 23:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 00:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 01:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 02:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 03:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 04:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 05:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 06:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 07:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 08:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 09:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 10:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 11:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 12:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 13:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 14:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 15:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 16:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 17:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 18:00:00+00:00        0.0     4000.0        20.0        25.0
# 2017-01-02 19:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 20:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 21:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 22:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-02 23:00:00+00:00        0.0     4000.0        12.0        30.0
# 2017-01-03 00:00:00+00:00        0.0     4000.0        12.0        30.0

# %%
opt_problem = optimization.Optimization(model,
                                        optimization.EnergyMin,
                                        optimization.JModelica,
                                        'Qflow',
                                        constraint_data = constraints.data)
opt_problem.optimize('1/2/2017', '1/3/2017')
opt_problem.get_optimization_statistics()
# Out:
# Warning: The option 'extra_lib_dirs' has been deprecated and will be removed. Please use the 'file_name' to pass additional libraries.
# Final Run Statistics: ---
#
#  Number of steps                                 : 431
#  Number of function evaluations                  : 722
#  Number of Jacobian evaluations                  : 9
#  Number of function eval. due to Jacobian eval.  : 18
#  Number of error test failures                   : 103
#  Number of nonlinear iterations                  : 718
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [1.e-08 3.e-06]
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0331320762634 seconds.
# Warning: Nominal trajectory for variable s1 is identically zero. Using nominal attribute instead.
# Warning: Nominal trajectory for variable s0 is identically zero. Using nominal attribute instead.
#
# Initialization time: 0.13 seconds
#
# Total time: 0.25 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.10 seconds
# Post-processing time: 0.02 seconds
# ('Solve_Succeeded', 26, 138434973.5151732, 0.100326)

# %%
opt_problem.display_measurements('Simulated').applymap('{:.2f}'.format)
# Out:
#                                     Qflow   Tzone
# Time
# 2017-01-02 06:00:00+00:00            0.00  303.25
# 2017-01-02 06:09:18.183693+00:00   890.62  294.09
# 2017-01-02 06:38:41.816307+00:00  2403.44  290.17
# 2017-01-02 07:00:00+00:00         2264.37  293.02
# 2017-01-02 07:09:18.183693+00:00  2356.65  293.02
# 2017-01-02 07:38:41.816307+00:00  2303.52  293.02
# 2017-01-02 08:00:00+00:00         2263.94  293.02
# 2017-01-02 08:09:18.183693+00:00  2272.04  293.02
# 2017-01-02 08:38:41.816307+00:00  2296.51  293.02
# 2017-01-02 09:00:00+00:00         2314.25  293.02
# 2017-01-02 09:09:18.183693+00:00  2306.50  293.02
# 2017-01-02 09:38:41.816307+00:00  2282.03  293.02
# 2017-01-02 10:00:00+00:00         2264.30  293.02
# 2017-01-02 10:09:18.183693+00:00  2237.96  293.02
# 2017-01-02 10:38:41.816307+00:00  2154.77  293.02
# 2017-01-02 11:00:00+00:00         2094.47  293.02
# 2017-01-02 11:09:18.183693+00:00  2094.47  293.02
# 2017-01-02 11:38:41.816307+00:00  2094.47  293.02
# 2017-01-02 12:00:00+00:00         2094.47  293.02
# 2017-01-02 12:09:18.183693+00:00  2086.73  293.02
# 2017-01-02 12:38:41.816307+00:00  2062.26  293.02
# 2017-01-02 13:00:00+00:00         2044.52  293.02
# 2017-01-02 13:09:18.183693+00:00  2044.52  293.02
# 2017-01-02 13:38:41.816307+00:00  2044.52  293.02
# 2017-01-02 14:00:00+00:00         2044.52  293.02
# 2017-01-02 14:09:18.183693+00:00  2035.23  293.02
# 2017-01-02 14:38:41.816307+00:00  2005.86  293.02
# 2017-01-02 15:00:00+00:00         1984.58  293.02
# 2017-01-02 15:09:18.183693+00:00  1975.29  293.02
# 2017-01-02 15:38:41.816307+00:00  1945.93  293.02
# ...                                   ...     ...
# 2017-01-02 20:09:18.183693+00:00  1194.69  285.02
# 2017-01-02 20:38:41.816307+00:00  1224.06  285.02
# 2017-01-02 21:00:00+00:00         1245.34  285.02
# 2017-01-02 22:00:00+00:00  1125.46  285.05
# 2017-01-02 23:00:00+00:00  1125.46  285.02
# 2017-01-03 00:00:00+00:00  1245.34  284.98
# 2017-01-03 01:00:00+00:00  1125.46  285.05
# 2017-01-03 02:00:00+00:00  1075.51  285.03
# 2017-01-03 03:00:00+00:00  1015.57  285.04
# 2017-01-03 04:00:00+00:00   965.63  285.03
# 2017-01-03 05:00:00+00:00  1185.40  284.95
# 2017-01-03 06:00:00+00:00  1078.55  284.54

# %%
opt_problem.optimize('1/2/2017', '1/3/2017', res_control_step=1.0)
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 534
#  Number of function evaluations                  : 817
#  Number of Jacobian evaluations                  : 11
#  Number of function eval. due to Jacobian eval.  : 22
#  Number of error test failures                   : 75
#  Number of nonlinear iterations                  : 813
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : [1.e-08 3.e-06]
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0400528907776 seconds.
# Warning: Nominal trajectory for variable s1 is identically zero. Using nominal attribute instead.
# Warning: Nominal trajectory for variable s0 is identically zero. Using nominal attribute instead.
#
# Initialization time: 0.12 seconds
#
# Total time: 0.24 seconds
# Pre-processing time: 0.00 seconds
# Solution time: 0.11 seconds
# Post-processing time: 0.01 seconds

# %%
model.control_data['Qflow'].display_data().loc[pd.to_datetime('1/2/2017 00:00:00'):pd.to_datetime('1/3/2017 00:00:00')].map('{:.2f}'.format)
# Out:
# 2017-01-02 00:00:00+00:00    3000.00
# 2017-01-02 01:00:00+00:00    3000.00
# 2017-01-02 02:00:00+00:00    3000.00
# 2017-01-02 03:00:00+00:00    3000.00
# 2017-01-02 04:00:00+00:00    3000.00
# 2017-01-02 05:00:00+00:00    3000.00
# 2017-01-02 06:00:00+00:00       0.00
# 2017-01-02 06:00:01+00:00       1.77
# 2017-01-02 06:00:02+00:00       3.54
# 2017-01-02 06:00:03+00:00       5.32
# 2017-01-02 06:00:04+00:00       7.09
# 2017-01-02 06:00:05+00:00       8.86
# 2017-01-02 06:00:06+00:00      10.63
# 2017-01-02 06:00:07+00:00      12.40
# 2017-01-02 06:00:08+00:00      14.16
# 2017-01-02 06:00:09+00:00      15.93
# 2017-01-02 06:00:10+00:00      17.70
# 2017-01-02 06:00:11+00:00      19.46
# 2017-01-02 06:00:12+00:00      21.23
# 2017-01-02 06:00:13+00:00      22.99
# 2017-01-02 06:00:14+00:00      24.76
# 2017-01-02 06:00:15+00:00      26.52
# 2017-01-02 06:00:16+00:00      28.29
# 2017-01-02 06:00:17+00:00      30.05
# 2017-01-02 06:00:18+00:00      31.81
# 2017-01-02 06:00:19+00:00      33.57
# 2017-01-02 06:00:20+00:00      35.33
# 2017-01-02 06:00:21+00:00      37.09
# 2017-01-02 06:00:22+00:00      38.85
# 2017-01-02 06:00:23+00:00      40.61
#                               ...
# 2017-01-02 23:59:31+00:00    1244.37
# 2017-01-02 23:59:32+00:00    1244.41
# 2017-01-02 23:59:33+00:00    1244.44
# 2017-01-02 23:59:34+00:00    1244.47
# 2017-01-02 23:59:35+00:00    1244.51
# 2017-01-02 23:59:36+00:00    1244.54
# 2017-01-02 23:59:37+00:00    1244.57
# 2017-01-02 23:59:38+00:00    1244.61
# 2017-01-02 23:59:39+00:00    1244.64
# 2017-01-02 23:59:40+00:00    1244.67
# 2017-01-02 23:59:41+00:00    1244.71
# 2017-01-02 23:59:42+00:00    1244.74
# 2017-01-02 23:59:43+00:00    1244.77
# 2017-01-02 23:59:44+00:00    1244.81
# 2017-01-02 23:59:45+00:00    1244.84
# 2017-01-02 23:59:46+00:00    1244.87
# 2017-01-02 23:59:47+00:00    1244.91
# 2017-01-02 23:59:48+00:00    1244.94
# 2017-01-02 23:59:49+00:00    1244.97
# 2017-01-02 23:59:50+00:00    1245.01
# 2017-01-02 23:59:51+00:00    1245.04
# 2017-01-02 23:59:52+00:00    1245.07
# 2017-01-02 23:59:53+00:00    1245.11
# 2017-01-02 23:59:54+00:00    1245.14
# 2017-01-02 23:59:55+00:00    1245.17
# 2017-01-02 23:59:56+00:00    1245.21
# 2017-01-02 23:59:57+00:00    1245.24
# 2017-01-02 23:59:58+00:00    1245.27
# 2017-01-02 23:59:59+00:00    1245.31
# 2017-01-03 00:00:00+00:00    1245.34
# Name: Qflow, Length: 64807, dtype: object

# %%
model.simulate('1/2/2017', '1/3/2017')
# Out:
# Final Run Statistics: ---
#
#  Number of steps                                 : 212
#  Number of function evaluations                  : 342
#  Number of Jacobian evaluations                  : 4
#  Number of function eval. due to Jacobian eval.  : 4
#  Number of error test failures                   : 43
#  Number of nonlinear iterations                  : 338
#  Number of nonlinear convergence failures        : 0
#
# Solver options:
#
#  Solver                   : CVode
#  Linear multistep method  : BDF
#  Nonlinear solver         : Newton
#  Linear solver type       : DENSE
#  Maximal order            : 5
#  Tolerances (absolute)    : 3e-06
#  Tolerances (relative)    : 1e-06
#
# Simulation interval    : 0.0 - 86400.0 seconds.
# Elapsed simulation time: 0.0156219005585 seconds.

# %%
model.display_measurements('Simulated').applymap('{:.2f}'.format)
# Out:
#                              Qflow   Tzone
# Time
# 2017-01-02 06:00:00+00:00     0.00  293.15
# 2017-01-02 07:00:00+00:00  2264.37  292.24
# 2017-01-02 08:00:00+00:00  2263.94  292.98
# 2017-01-02 09:00:00+00:00  2314.25  293.01
# 2017-01-02 10:00:00+00:00  2264.30  293.02
# 2017-01-02 11:00:00+00:00  2094.47  293.02
# 2017-01-02 12:00:00+00:00  2094.47  293.02
# 2017-01-02 13:00:00+00:00  2044.52  293.02
# 2017-01-02 14:00:00+00:00  2044.52  293.02
# 2017-01-02 15:00:00+00:00  1984.58  293.02
# 2017-01-02 16:00:00+00:00  1924.64  293.02
# 2017-01-02 17:00:00+00:00  1814.76  293.02
# 2017-01-02 18:00:00+00:00  1814.76  293.02
# 2017-01-02 19:00:00+00:00   749.37  285.02
# 2017-01-02 20:00:00+00:00  1185.40  285.02
# 2017-01-02 21:00:00+00:00  1245.34  285.02
# 2017-01-02 22:00:00+00:00  1125.46  285.02
# 2017-01-02 23:00:00+00:00  1125.46  285.02
# 2017-01-03 00:00:00+00:00  1245.34  285.02
# 2017-01-03 01:00:00+00:00  1125.46  285.02
# 2017-01-03 02:00:00+00:00  1075.51  285.02
# 2017-01-03 03:00:00+00:00  1015.57  285.02
# 2017-01-03 04:00:00+00:00   965.63  285.02
# 2017-01-03 05:00:00+00:00  1185.40  285.02
# 2017-01-03 06:00:00+00:00  1078.55  284.61

# %%
plt.plot(model.display_measurements('Simulated').applymap('{:.2f}'.format))
# Out:
# [<matplotlib.lines.Line2D at 0x7f67813c1610>,
#  <matplotlib.lines.Line2D at 0x7f678133a5d0>]

# %%
plt.plot(model.display_measurements('Simulated')['Tzone'])
